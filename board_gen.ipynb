# %%
from data_gen import train_x, train_y

for i, j in zip(train_x[0:5],train_y[0:5]):
    print("\n========= \t\t=========")
    lc = 0
    rc = 0
    for c in range(len(i)):
        if i[c] == '0':
            print(".",end="")
        else:
            print(i[c],end="")
        if (c+1) % 9 == 0:
            rc = c+1
            print("\t\t",end="")
            for z in range(lc,rc):
                print(j[z],end="")
            lc = rc
            print("")
    print("========= \t\t=========")
# Out:
# ========= 		=========
# ..43..2.9		864371259
# ..5..9..1		325849761
# .7..6..43		971265843
# ..6..2.87		436192587
# 19...74..		198657432
# .5..83...		257483916
# 6.....1.5		689734125
# ..35.869.		713528694
# .4291.3..		542916378
# ========= 		=========
#
# ========= 		=========
# .4.1...5.		346179258
# 1.7..396.		187523964
# 52...8...		529648371
# .......17		965832417
# ...9.68..		472916835
# 8.3.5.62.		813754629
# .9..6.543		798261543
# 6...8.7..		631485792
# 25..971..		254397186
# ========= 		=========
#
# ========= 		=========
# 6..12.384		695127384
# ..8459.72		138459672
# .....6..5		724836915
# ...264.3.		851264739
# .7..8...6		273981546
# 94...3...		946573821
# 31.....5.		317692458
# .897.....		489715263
# 5.2...19.		562348197
# ========= 		=========
#
# ========= 		=========
# 4972.....		497258316
# 1..4....5		186439725
# ....16.98		253716498
# 62.3...4.		629381547
# 3..9.....		375964182
# ..1.726..		841572639
# ..2..587.		962145873
# ...6....4		718623954
# ...
