# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import numpy as np
import data_gen
# To Avoid GPU errors
physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# (x_train, y_train), (x_test, y_test) = mnist.load_data()
# x_train = x_train.reshape(-1, 28 * 28).astype("float32") / 255.0
# x_test = x_test.reshape(-1, 28 * 28).astype("float32") / 255.0

# %% [markdown]
# *TRYING DATA AS STRINGS*

# %%
model = keras.Sequential([layers.Dense(81, activation='relu'),layers.Dense(81*2, activation='relu'),layers.Dense(81*4, activation='softmax'),layers.Dense(81*2, activation='softmax'),layers.Dense(81, activation='tanh')])

# %%
model.compile(
    loss=keras.losses.CategoricalCrossentropy(from_logits=False),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
    run_eagerly=True,
)

# %%
x_train = []
y_train = []
for i, j in zip(data_gen.train_x, data_gen.train_y):
    x_train.append([float(k) for k in i])
    y_train.append([float(k) for k in j])
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
x_train = x_train.reshape(-1,81).astype("float32")
y_train = y_train.reshape(-1,81).astype("float32")

# %%
np.shape(x_train)
np.shape(y_train)
# Out:
# (500000, 81)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/darsh/devel/sudoku_solver/solver.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/home/darsh/devel/sudoku_solver/solver.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> model.summary()
#
# File ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3482, in Model.summary(self, line_length, positions, print_fn, expand_nested, show_trainable, layer_range)
#    3451 """Prints a string summary of the network.
#    3452
#    3453 Args:
#    (...)
#    3479     ValueError: if `summary()` is called before the model is built.
#    3480 """
#    3481 if not self.built:
# -> 3482     raise ValueError(
#    3483         "This model has not yet been built. "
#    3484         "Build the model first by calling `build()` or by calling "
#    3485         "the model on a batch of data."
#    3486     )
#    3487 layer_utils.print_summary(
#    3488     self,
#    3489     line_length=line_length,
#    (...)
#    3494     layer_range=layer_range,
#    3495 )
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %%
model.fit(x_train, y_train, batch_size=100, epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 5000/5000 - 86s - loss: 3990.9207 - accuracy: 0.1088 - 86s/epoch - 17ms/step
# Epoch 2/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32901/4227558751.py in ?()
# ----> 1 model.fit(x_train, y_train, batch_size=100, epochs=20, verbose=2)
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1779                             batch_size=batch_size,
#    1780                             _r=1,
#    1781                         ):
#    1782                             callbacks.on_train_batch_begin(step)
# -> 1783                             tmp_logs = self.train_function(iterator)
#    1784                             if data_handler.should_sync:
#    1785                                 context.async_wait()
#    1786                             # No error, now safe to assign to logs.
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in ?(iterator)
#    1375             def train_function(iterator):
#    1376                 """Runs a training execution with a single step."""
# -> 1377                 return step_function(self, iterator)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in ?(model, iterator)
#    1356                 run_step = tf.function(
#    1357                     run_step, jit_compile=True, reduce_retracing=True
#    1358                 )
#    1359             data = next(iterator)
# -> 1360             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1361             outputs = reduce_per_replica(
#    1362                 outputs,
#    1363                 self.distribute_strategy,
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(***failed resolving arguments***)
#    1675       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1676       # applied when the caller is also in Eager mode.
#    1677       fn = autograph.tf_convert(
#    1678           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1679       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, fn, args, kwargs)
#    3265     _require_cross_replica_or_default_context_extended(self)
#    3266     if kwargs is None:
#    3267       kwargs = {}
#    3268     with self._container_strategy().scope():
# -> 3269       return self._call_for_each_replica(fn, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, fn, args, kwargs)
#    4065   def _call_for_each_replica(self, fn, args, kwargs):
#    4066     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4067       return fn(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(*args, **kwargs)
#     594   def wrapper(*args, **kwargs):
#     595     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596       return func(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in ?(data)
#    1348             def run_step(data):
# -> 1349                 outputs = model.train_step(data)
#    1350                 # Ensure counter is updated only if `train_step` succeeds.
#    1351                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#    1352                     model._train_counter.assign_add(1)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in ?(self, data)
#    1123         x, y, sample_weight = data_adapter.unpack_x_y_sample_weight(data)
#    1124         # Run forward pass.
#    1125         with tf.GradientTape() as tape:
#    1126             y_pred = self(x, training=True)
# -> 1127             loss = self.compute_loss(x, y, y_pred, sample_weight)
#    1128         self._validate_target_and_loss(y, loss)
#    1129         # Run backwards pass.
#    1130         self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/training.py in ?(***failed resolving arguments***)
#    1181           The total loss as a `tf.Tensor`, or `None` if no loss results (which
#    1182           is the case when called by `Model.test_step`).
#    1183         """
#    1184         del x  # The default implementation does not use `x`.
# -> 1185         return self.compiled_loss(
#    1186             y, y_pred, sample_weight, regularization_losses=self.losses
#    1187         )
#
# ~/.local/lib/python3.10/site-packages/keras/src/engine/compile_utils.py in ?(self, y_true, y_pred, sample_weight, regularization_losses)
#     273                 continue
#     274
#     275             y_t, y_p, sw = match_dtype_and_rank(y_t, y_p, sw)
#     276             sw = losses_utils.apply_mask(y_p, sw, losses_utils.get_mask(y_p))
# --> 277             loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     278
#     279             total_loss_mean_value = loss_value
#     280             # Correct for the `Mean` loss metrics counting each replica as a
#
# ~/.local/lib/python3.10/site-packages/keras/src/losses.py in ?(self, y_true, y_pred, sample_weight)
#     139                 call_fn = tf.__internal__.autograph.tf_convert(
#     140                     self.call, tf.__internal__.autograph.control_status_ctx()
#     141                 )
#     142
# --> 143             losses = call_fn(y_true, y_pred)
#     144
#     145             in_mask = losses_utils.get_mask(y_pred)
#     146             out_mask = losses_utils.get_mask(losses)
#
# ~/.local/lib/python3.10/site-packages/keras/src/losses.py in ?(self, y_true, y_pred)
#     266
#     267         ag_fn = tf.__internal__.autograph.tf_convert(
#     268             self.fn, tf.__internal__.autograph.control_status_ctx()
#     269         )
# --> 270         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/keras/src/losses.py in ?(y_true, y_pred, from_logits, label_smoothing, axis)
#    2217     y_true = tf.__internal__.smart_cond.smart_cond(
#    2218         label_smoothing, _smooth_labels, lambda: y_true
#    2219     )
#    2220
# -> 2221     return backend.categorical_crossentropy(
#    2222         y_true, y_pred, from_logits=from_logits, axis=axis
#    2223     )
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/keras/src/backend.py in ?(target, output, from_logits, axis)
#    5589     output = output / tf.reduce_sum(output, axis, True)
#    5590
#    5591     # Compute cross entropy from probabilities.
#    5592     epsilon_ = _constant_to_tensor(epsilon(), output.dtype.base_dtype)
# -> 5593     output = tf.clip_by_value(output, epsilon_, 1.0 - epsilon_)
#    5594     return -tf.reduce_sum(target * tf.math.log(output), axis)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/clip_ops.py in ?(t, clip_value_min, clip_value_max, name)
#     105         t.values if isinstance(t, indexed_slices.IndexedSlices) else t,
#     106         name="t")
#     107
#     108     # Go through list of tensors, for each value in each tensor clip
# --> 109     t_min = math_ops.minimum(values, clip_value_max)
#     110     # Assert that the shape is compatible with the initial shape,
#     111     # to prevent unintentional broadcasting.
#     112     values.shape.assert_is_compatible_with(t_min.shape)
#
# ~/.local/lib/python3.10/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#    6601         _ctx, "Minimum", name, x, y)
#    6602       return _result
#    6603     except _core._NotOkStatusException as e:
#    6604       _ops.raise_from_not_ok_status(e, name)
# -> 6605     except _core._FallbackException:
#    6606       pass
#    6607     try:
#    6608       _result = _dispatcher_for_minimum(
#
# KeyboardInterrupt:
